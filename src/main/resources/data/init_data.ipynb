# %% [markdown]
# # 향수 상세정보 크롤링 데이터 적재 스크립트
# ## 관련 테이블 정보
# - evaluation_code, evaluation_field_option, fragrantica_evaluation
# - perfume, perfume_brand
# - pefume_accord, note, perfume_note
#
# ## TODO
# - 이슈 사항에 대한 처리
# - perfume_brand: image_url 추가
# - perfume: image_url에 대해 프로젝트 내 이미지 경로로 변경(현재 프라그란티카 url)
# - 한영 dictionary를 이용하여 한글로 변환 후 적재하는 로직 추가

# %%
# !pip install pymysql
# !pip install python-dotenv
# Out:
# Requirement already satisfied: pymysql in /opt/anaconda3/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.12/site-packages (0.21.0)

# %%
# test
from dotenv import load_dotenv
import pymysql

load_dotenv()

# MySQL 연결 설정
conn = pymysql.connect(
    host=os.getenv('DB_HOST'), 
    port=int(os.getenv('DB_PORT')),
    user=os.getenv('DB_USER'), 
    password=os.getenv('DB_PASSWORD'), 
    db=os.getenv('DB_NAME'), 
    charset='utf8'
)

cursor = conn.cursor()

sql = "SHOW TABLES;"
cursor.execute(sql)
result = cursor.fetchall()
for table in result:
    print(table[0])

conn.commit()
conn.close()
# Out:
# accord
# brand
# complaint
# evaluation_statistic
# flyway_schema_history
# fragrantica_evaluation
# likes
# mood
# note
# perfume
# perfume_accord
# review
# review_evaluation
# review_mood
# star_rating
# star_rating_statistic
# user
# user_accord

# %%
import os
import json

# JSON 데이터
DIRECTORY_PATH = './crawling_data'
JSON_DATA_LIST = []
for filename in os.listdir(DIRECTORY_PATH):
    if filename.endswith('.json'):
        file_path = os.path.join(DIRECTORY_PATH, filename)
        
        with open(file_path, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
            JSON_DATA_LIST.append(data)

print(JSON_DATA_LIST[0])
# Out:
# [{'perfume_name': 'Daisy Love', 'brand_name': 'Marc Jacobs', 'image_src': 'https://fimgs.net/mdimg/perfume/375x500.49108.jpg', 'main_accords': {'fruity': 100.0, 'musky': 90.7088, 'floral': 68.6425, 'aromatic': 65.0, 'woody': 63.7858, 'sweet': 61.8327, 'powdery': 60.3544, 'marine': 51.1162, 'herbal': 49.3215, 'green': 46.1011}, 'notes': {'Top Notes': ['Cloudberry'], 'Middle Notes': ['Daisy'], 'Base Notes': ['Cashmere Musk', 'Driftwood'], 'Undefineded': []}, 'season_data': {'spring': 93.279, 'summer': 80.0407, 'fall': 30.8554, 'winter': 15.6823, 'day': 100.0, 'night': 18.7373}, 'perfume_properties': {'LONGEVITY': {'very weak': 100, 'weak': 290, 'moderate': 553, 'long lasting': 172, 'eternal': 40}, 'SILLAGE': {'intimate': 373, 'moderate': 609, 'strong': 132, 'enormous': 79}, 'GENDER': {'female': 838, 'more female': 69, 'unisex': 9, 'more male': 0, 'male': 4}, 'PRICE VALUE': {'way overpriced': 38, 'overpriced': 162, 'ok': 453, 'good value': 162, 'great value': 28}}}, {'perfume_name': 'Daisy Eau So Fresh', 'brand_name': 'Marc Jacobs', 'image_src': 'https://fimgs.net/mdimg/perfume/375x500.10858.jpg', 'main_accords': {'fruity': 100.0, 'sweet': 65.6754, 'green': 64.0367, 'floral': 54.6267, 'violet': 54.2163, 'powdery': 54.024, 'fresh': 53.3869, 'citrus': 47.5205, 'rose': 45.4728}, 'notes': {'Top Notes': ['Green Notes', 'Raspberry', 'Pear', 'Grapefruit'], 'Middle Notes': ['Violet', 'Litchi', 'Apple Blossom', 'Rose', 'Jasmine'], 'Base Notes': ['Musk', 'Plum', 'Virginia Cedar'], 'Undefineded': []}, 'season_data': {'spring': 90.7566, 'summer': 80.2087, 'fall': 11.8151, 'winter': 6.63436, 'day': 100.0, 'night': 8.64704}, 'perfume_properties': {'LONGEVITY': {'very weak': 279, 'weak': 726, 'moderate': 951, 'long lasting': 248, 'eternal': 80}, 'SILLAGE': {'intimate': 976, 'moderate': 997, 'strong': 230, 'enormous': 161}, 'GENDER': {'female': 1065, 'more female': 111, 'unisex': 23, 'more male': 0, 'male': 2}, 'PRICE VALUE': {'way overpriced': 49, 'overpriced': 199, 'ok': 574, 'good value': 213, 'great value': 36}}}, {'perfume_name': 'Daisy Dream', 'brand_name': 'Marc Jacobs', 'image_src': 'https://fimgs.net/mdimg/perfume/375x500.25289.jpg', 'main_accords': {'fruity': 100.0, 'floral': 71.3155, 'fresh': 67.7034, 'sweet': 57.5473, 'musky': 48.0385, 'white floral': 47.8928, 'citrus': 47.5027, 'fresh spicy': 46.5721, 'tropical': 46.4187, 'aquatic': 44.571}, 'notes': {'Top Notes': ['Blackberry', 'Pear', 'Grapefruit'], 'Middle Notes': ['Wisteria', 'Litchi', 'Jasmine'], 'Base Notes': ['Musk', 'White Wood', 'Coconut Water'], 'Undefineded': []}, 'season_data': {'spring': 91.9837, 'summer': 80.5707, 'fall': 12.3641, 'winter': 9.23913, 'day': 100.0, 'night': 7.88043}, 'perfume_properties': {'LONGEVITY': {'very weak': 339, 'weak': 467, 'moderate': 559, 'long lasting': 91, 'eternal': 34}, 'SILLAGE': {'intimate': 752, 'moderate': 577, 'strong': 123, 'enormous': 105}, 'GENDER': {'female': 737, 'more female': 125, 'unisex': 25, 'more male': 1, 'male': 0}, 'PRICE VALUE': {'way overpriced': 37, 'overpriced': 163, 'ok': 403, 'good value': 170, 'great value': 23}}}, {'perfume_name': 'Perfect', 'brand_name': 'Marc Jacobs', 'image_src': 'https://fimgs.net/mdimg/perfume/375x500.62021.jpg', 'main_accords': {'green': 100.0, 'fruity': 98.8511, 'almond': 86.9949, 'aromatic': 74.5026, 'woody': 72.406, 'sweet': 70.125, 'yellow floral': 66.6732, 'nutty': 64.1971, 'powdery': 52.4189, 'musky': 52.1734}, 'notes': {'Top Notes': ['Rhubarb', 'Narcissus'], 'Middle Notes': ['Almond Milk'], 'Base Notes': ['Cashmeran', 'Cedar'], 'Undefineded': []}, 'season_data': {'spring': 100.0, 'summer': 82.3903, 'fall': 32.9943, 'winter': 19.0718, 'day': 99.1736, 'night': 17.9911}, 'perfume_properties': {'LONGEVITY': {'very weak': 133, 'weak': 350, 'moderate': 1038, 'long lasting': 195, 'eternal': 44}, 'SILLAGE': {'intimate': 458, 'moderate': 1023, 'strong': 193, 'enormous': 72}, 'GENDER': {'female': 1410, 'more female': 253, 'unisex': 68, 'more male': 5, 'male': 7}, 'PRICE VALUE': {'way overpric ...

# %%
# code set
evaluation_codes = {
	"LONGEVITY": {
		"code": "EF001",
		"name": "지속력",
		"type": "FIELD",
		"options": {
			"very weak": {
				"code": "EO101",
				"name": "매우 약함",
				"type": "OPTION"
			},
			"weak": {
				"code": "EO102",
				"name": "약함",
				"type": "OPTION"
			},
			"moderate": {
				"code": "EO103",
				"name": "보통",
				"type": "OPTION"
			},
			"long lasting": {
				"code": "EO104",
				"name": "오래감",
				"type": "OPTION"
			},
			"eternal": {
				"code": "EO105",
				"name": "매우 오래감",
				"type": "OPTION"
			}
		}
	},
	"SILLAGE": {
		"code": "EF002",
		"name": "시야주",
		"type": "FIELD",
		"options": {
			"intimate": {
				"code": "EO201",
				"name": "향 여운이 약함",
				"type": "OPTION"
			},
			"moderate": {
				"code": "EO202",
				"name": "보통",
				"type": "OPTION"
			},
			"strong": {
				"code": "EO203",
				"name": "향 여운이 강함",
				"type": "OPTION"
			},
			"enormous": {
				"code": "EO204",
				"name": "향 여운이 매우 강함",
				"type": "OPTION"
			}
		}
	},
	"seasonData": {
		"code": "EF003",
		"name": "계절감/시간",
		"type": "FIELD",
		"options": {
			"spring": {
				"code": "EO301",
				"name": "봄",
				"type": "OPTION"
			},
			"summer": {
				"code": "EO302",
				"name": "여름",
				"type": "OPTION"
			},
			"fall": {
				"code": "EO303",
				"name": "가을",
				"type": "OPTION"
			},
			"winter": {
				"code": "EO304",
				"name": "겨울",
				"type": "OPTION"
			},
			"day": {
				"code": "EO305",
				"name": "낮",
				"type": "OPTION"
			},
			"night": {
				"code": "EO306",
				"name": "밤",
				"type": "OPTION"
			}
		}
	},
	"GENDER": {
		"code": "EF004",
		"name": "성별",
		"type": "FIELD",
		"options": {
			"male": {
				"code": "EO401",
				"name": "남성",
				"type": "OPTION"
			},
			"more male": {
				"code": "EO402",
				"name": "남성에 가까운",
				"type": "OPTION"
			},
			"unisex": {
				"code": "EO403",
				"name": "중성",
				"type": "OPTION"
			},
			"more female": {
				"code": "EO404",
				"name": "여성에 가까운",
				"type": "OPTION"
			},
			"female": {
				"code": "EO405",
				"name": "여성",
				"type": "OPTION"
			}
		}
	}
}


# moods
moods = [
    "귀여운",
    "관능적인",
    "청순한",
    "우아한",
    "섹시한",
    "스포티한",
    "중후한",
    "마초적인",
    "케주얼한",
    "편안한",
    "깔끔한",
    "세련된"
]

# brands
brands = {
	"Chanel": { "brand_name": "샤넬", "display_order": 1 },
	"Jo Malone London": { "brand_name": "조말론", "display_order": 2 },
	"Diptyque": { "brand_name": "딥디크", "display_order": 3 },
	"Dior": { "brand_name": "크리스찬디올", "display_order": 4 },
	"Tom Ford": { "brand_name": "톰포드", "display_order": 5 },
	"Bvlgari": { "brand_name": "불가리", "display_order": 6 },
	"Byredo": { "brand_name": "바이레도", "display_order": 7 },
	"Creed": { "brand_name": "크리드", "display_order": 8 },
	"Lanvin": { "brand_name": "랑방", "display_order": 9 },
	"Burberry": { "brand_name": "버버리", "display_order": 10 },
	"Gucci": { "brand_name": "구찌", "display_order": 11 },
	"Le Labo": { "brand_name": "르라보", "display_order": 12 },
	"Chloé": { "brand_name": "끌로에", "display_order": 13 },
	"Versace": { "brand_name": "베르사체", "display_order": 14 },
	"Lush": { "brand_name": "러쉬", "display_order": 15 },
	"Montblanc": { "brand_name": "몽블랑", "display_order": 16 },
	"Jimmy Choo": { "brand_name": "지미추", "display_order": 17 },
	"Clean": { "brand_name": "클린", "display_order": 18 },
	"Kenzo": { "brand_name": "겐조", "display_order": 19 },
	"Marc Jacobs": { "brand_name": "마크제이콥스", "display_order": 20 },
	"Acqua di Parma": { "brand_name": "아쿠아디파르마", "display_order": 21 },
	"John Varvatos": { "brand_name": "존바바토스", "display_order": 22 },
	"Ferrari": { "brand_name": "페라리", "display_order": 23 },
	"Kiehl's": { "brand_name": "키엘", "display_order": 24 },
	"Lolita Lempicka": { "brand_name": "롤리타렘피카", "display_order": 25 },
	"Calvin Klein": { "brand_name": "캘빈클라인", "display_order": 26 },
	"Penhaligon's": { "brand_name": "펜할리곤스", "display_order": 27 },
	"Salvatore Ferragamo": {
		"brand_name": "살바토레페라가모",
		"display_order": 28
	},
	"Giorgio Armani": { "brand_name": "조르지오아르마니", "display_order": 29 }
}

# %%
from datetime import datetime

def generate_id():
    '''
    현재 시간을 yyyyMMddHHmmssSSSSS 형식으로 포맷팅 후 int로 변환
    '''
    return int(datetime.now().strftime('%Y%m%d%H%M%S%f')[:-1])

def get_or_generate_id(query, variables):
    cursor.execute(query, variables)
    result = cursor.fetchone()
    return generate_id() if result == None else result[0]

# %%
# sql_queries

# insert
insert_brand_query = (
    "INSERT INTO "
    "brand(brand_name, image_url, display_order) "
    "VALUES(%s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "image_url = VALUES(image_url);"
)

insert_perfume_query = (
    "INSERT INTO "
    "perfume("
    "perfume_id, brand_name, perfume_name, image_url"
    ") "
    "VALUES(%s, %s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "image_url = VALUES(image_url);"
)

insert_fragrantica_evaluation_query = (
    "INSERT INTO "
    "fragrantica_evaluation("
    "perfume_id, field_code, option_code, votes"
    ") "
    "VALUES(%s, %s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "votes = VALUES(votes);"
)

insert_note_query = (
    "INSERT IGNORE INTO "
    "note(perfume_id, note_name, note_type) "
    "VALUES(%s, %s, %s);"
)

insert_mood_query = (
    "INSERT IGNORE INTO "
    "mood(mood_name) "
    "VALUES(%s);"
)

insert_accord_query = (
    "INSERT IGNORE INTO "
    "accord(accord_name) "
    "VALUES(%s);"
)

insert_perfume_accord_query = (
    "INSERT INTO "
    "perfume_accord("
    "perfume_id, accord_name, value"
    ") "
    "VALUES(%s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "value = VALUES(value);"
)

# select id
select_perfume_perfume_id_query = (
    "SELECT perfume_id "
    "FROM perfume "
    "WHERE brand_name=%s AND perfume_name=%s;"
)

# %%
import pymysql
            
# MySQL 연결 설정
conn = pymysql.connect(
    host=os.getenv('DB_HOST'), 
    port=int(os.getenv('DB_PORT')),
    user=os.getenv('DB_USER'), 
    password=os.getenv('DB_PASSWORD'), 
    db=os.getenv('DB_NAME'), 
    charset='utf8'
)

cursor = conn.cursor()

print("===========start inserting default setting...===========")
print("mood>>> start...")
for mood_name in moods:
    cursor.execute(
            insert_mood_query, 
            (mood_name)
        )
print("mood>>> ...end.")


print("===========start inserting crawl data...===========")

field_key_list = ["seasonData", "LONGEVITY", "SILLAGE", "GENDER"]

for brand_data in JSON_DATA_LIST:
    for perfume_data in brand_data:
        # perfume_brand
        # TODO: 초기 display_order, image_url 추가
        brand = perfume_data['brand_name']
        brand_name = brands[brand]["brand_name"]
        display_order = brands[brand]["display_order"]
        cursor.execute(insert_brand_query, (brand_name, '', display_order))
        
        # perfume 
        # TODO: image_url에 대해 s3 url로 변경(현재 프라그란티카 url)
        perfume_name = perfume_data['perfume_name']
        print(f"start: {brand_name} > {perfume_name}")
        
        perfume_id = get_or_generate_id(
            select_perfume_perfume_id_query,
            (brand_name, perfume_name)
        )
        image_url = perfume_data.get('image_src')
        cursor.execute(
            insert_perfume_query, 
            (perfume_id, brand_name, perfume_name, image_url)
        )
        
        # fragrantica_evaluation(seasonData)
        field_code = evaluation_codes['seasonData']['code']
        for option_key, votes in perfume_data['season_data'].items():
            option_code = evaluation_codes['seasonData']['options'][option_key]['code']
            cursor.execute(
                insert_fragrantica_evaluation_query, 
                (perfume_id, field_code, option_code, votes)
            )
        
        # fragrantica_evaluation(perfumeProperties)
        for field_key, field_data in perfume_data['perfume_properties'].items():
            if (field_key not in field_key_list): continue;
            field_code = evaluation_codes[field_key]['code']
            
            for option_key, votes in field_data.items():
                option_code = evaluation_codes[field_key]['options'][option_key]['code']
                cursor.execute(
                    insert_fragrantica_evaluation_query, 
                    (perfume_id, field_code, option_code, votes)
                )
        
        # accord & perfume_accord
        for accord_name, accord_value in perfume_data['main_accords'].items():
            cursor.execute(
                insert_accord_query,
                (accord_name)
            )
            cursor.execute(
                insert_perfume_accord_query, 
                (perfume_id, accord_name, accord_value)
            )
        
        
        if (perfume_data['notes'].get("Top Notes")):
            for note_name in perfume_data['notes'].get("Top Notes"):
                # note
                note_type = "TOP"
                cursor.execute(
                    insert_note_query,
                    (perfume_id, note_name, note_type)
                )
                
                
                
        if (perfume_data['notes'].get("Middle Notes")):
            for note_name in perfume_data['notes'].get("Middle Notes"):
                # note
                note_type = "MIDDLE"
                cursor.execute(
                    insert_note_query,
                    (perfume_id, note_name, note_type)
                )
                
        
        if (perfume_data['notes'].get("Base Notes")):
            for note_name in perfume_data['notes'].get("Base Notes"):
                # note
                note_type = "BASE"
                cursor.execute(
                    insert_note_query,
                    (perfume_id, note_name, note_type)
                )

        if (perfume_data['notes'].get("Undefineded")):
            for note_name in perfume_data['notes'].get("Undefineded"):
                # note
                note_type = "NOT_DEFINED"
                cursor.execute(
                    insert_note_query,
                    (perfume_id, note_name, note_type)
                )
        print(f"no error: {brand_name} > {perfume_name}")
        
        
conn.commit()
print("===========perfume data committed.===========")

cursor.close()
conn.close()
# Out:
# ===========start inserting default setting...===========
# mood>>> start...
# mood>>> ...end.
# ===========start inserting crawl data...===========
# start: 마크제이콥스 > Daisy Love
# no error: 마크제이콥스 > Daisy Love
# start: 마크제이콥스 > Daisy Eau So Fresh
# no error: 마크제이콥스 > Daisy Eau So Fresh
# start: 마크제이콥스 > Daisy Dream
# start: 클린 > Pure Soap
# no error: 클린 > Pure Soap
# start: 클린 > Fresh Linens
# no error: 클린 > Fresh Linens
# start: 클린 > Rain
# no error: 클린 > Rain
# start: 클린 > Warm Cotton [Reserve Blend]
# no error: 클린 > Warm Cotton [Reserve Blend]
# start: 클린 > Acqua Neroli
# no error: 클린 > Acqua Neroli
# start: 클린 > Citron Fig
# no error: 클린 > Citron Fig
# start: 클린 > Sueded Oud
# no error: 클린 > Sueded Oud
# start: 클린 > Skin
# no error: 클린 > Skin
# start: 클린 > Radiant Nectar
# no error: 클린 > Radiant Nectar
# start: 클린 > Clean Classic Flower Fresh
# no error: 클린 > Clean Classic Flower Fresh
# start: 클린 > Clean Air
# no error: 클린 > Clean Air
# start: 페라리 > Ferrari Black
# no error: 페라리 > Ferrari Black
# start: 페라리 > Scuderia Ferrari Light Essence Bright
# no error: 페라리 > Scuderia Ferrari Light Essence Bright
# start: 페라리 > Noble Fig
# no error: 페라리 > Noble Fig
# start: 페라리 > Cedar Essence
# no error: 페라리 > Cedar Essence
# start: 페라리 > Bright Neroli
# no error: 페라리 > Bright Neroli
# start: 페라리 > Ferrari Light Essence
# no error: 페라리 > Ferrari Light Essence
# start: 페라리 > Vetiver Essence
# no error: 페라리 > Vetiver Essence
# start: 페라리 > Red Power
# no error: 페라리 > Red Power
# start: 페라리 > Ferrari Uomo
# no error: 페라리 > Ferrari Uomo
# start: 페라리 > Pure Lavender
# no error: 페라리 > Pure Lavender
# start: 끌로에 > Chloe Eau de Parfum
# no error: 끌로에 > Chloe Eau de Parfum
# start: 끌로에 > Nomade
# no error: 끌로에 > Nomade
# start: 끌로에 > Chloé L'Eau Eau de Toilette
# no error: 끌로에 > Chloé L'Eau Eau de Toilette
# start: 끌로에 > Chloé Roses de Chloé
# no error: 끌로에 > Chloé Roses de Chloé
# start: 끌로에 > Chloé Rose Tangerine
# no error: 끌로에 > Chloé Rose Tangerine
# start: 끌로에 > Chloé Eau de Parfum Naturelle
# no error: 끌로에 > Chloé Eau de Parfum Naturelle
# start: 끌로에 > Love Story
# no error: 끌로에 > Love Story
# start: 끌로에 > Chloé Rose Naturelle Intense Chloé
# no error: 끌로에 > Chloé Rose Naturelle Intense Chloé
# start: 끌로에 > Jasminum Sambac
# no error: 끌로에 > Jasminum Sambac
# start: 끌로에 > Nomade Naturelle Eau de Parfum
# no error: 끌로에 > Nomade Naturelle Eau de Parfum
# start: 끌로에 > Nomade Absolu de Parfum
# no error: 끌로에 > Nomade Absolu de Parfum
# start: 베르사체 > Bright Crystal Absolu
# no error: 베르사체 > Bright Crystal Absolu
# start: 베르사체 > Bright Crystal
# no error: 베르사체 > Bright Crystal
# start: 베르사체 > Eros
# no error: 베르사체 > Eros
# start: 베르사체 > Versace Pour Homme
# no error: 베르사체 > Versace Pour Homme
# start: 베르사체 > Red Jeans
# no error: 베르사체 > Red Jeans
# start: 베르사체 > The Dreamer
# no error: 베르사체 > The Dreamer
# start: 베르사체 > Versace Pour Homme Dylan Blue
# no error: 베르사체 > Versace Pour Homme Dylan Blue
# start: 베르사체 > Santal Boisé
# no error: 베르사체 > Santal Boisé
# start: 베르사체 > Crystal Noir Eau de Toilette
# no error: 베르사체 > Crystal Noir Eau de Toilette
# start: 베르사체 > Eros Pour Femme
# no error: 베르사체 > Eros Pour Femme
# start: 베르사체 > Eros Flame
# no error: 베르사체 > Eros Flame
# start: 베르사체 > Versace Pour Femme Dylan Blue
# no error: 베르사체 > Versace Pour Femme Dylan Blue
# start: 베르사체 > Eros Eau de Parfum
# no error: 베르사체 > Eros Eau de Parfum
# start: 크리드 > Aventus
# no error: 크리드 > Aventus
# start: 크리드 > Love in White
# no error: 크리드 > Love in White
# start: 크리드 > Tabarome
# no error: 크리드 > Tabarome
# start: 크리드 > Aventus for Her
# no error: 크리드 > Aventus for Her
# start: 크리드 > Virgin Island Water
# no error: 크리드 > Virgin Island Water
# start: 크리드 > Green Irish Tweed
# no error: 크리드 > Green Irish Tweed
# start: 크리드 > Queen of Silk
# no error: 크리드 > Queen of Silk
# start: 크리드 > Silver Mountain Water
# no error: 크리드 > Silver Mountain Water
# start: 크리드 > Millésime Impérial
# no error: 크리드 > Millésime Impérial
# start: 크리드 > Acqua Fiorentina
# no error: 크리드 > Acqua Fiorentina
# start: 크리드 > Original Vetiver
# no error: 크리드 > Original Vetiver
# start: 크리드 > Royal Mayfair
# no error: 크리드 > Royal Mayfair
# start: 크리드 > Zeste Mandarine
# no error: 크리드 > Zeste Mandarine
# start: 크리드 > Spring Flower
# no error: 크리드 > Spring Flower
# start: 크리드 > Wind Flowers
# no error: 크리드 > Wind Flowers
# start: 크리드 > Love in White for Summer
# no error: 크리드 > Love in White for Summer
# start: 크리드 > Vetiver Geranium
# no error: 크리드 > Vetiver Geranium
# start: 크리드 > Floralie
# no error: 크리드 > Floralie
# start: 크리드 > Vetiver
# no error: 크리드 > Vetiver
# start: 크리드 > Royal Water
# no error: 크리드 > Royal Water
# start: 크리드 > Aventus Cologne
# no error: 크리드 > Aventus Cologne
# start: 크리드 > Himalaya
# no error: 크리드 > Himalaya
# ===========perfume data committed.===========

# %% [markdown]
# # 이슈: 필요 데이터가 없는 경우 확인

# %%
total_perfume_count = 0
note_error_perfume_count = 0
image_not_exist_perfume_count = 0

print("===========start checking===========")
for brand_data in JSON_DATA_LIST:
    total_perfume_count += len(brand_data)
    for perfume_data in brand_data:
        # perfume_brand
        brand_name = perfume_data['brand_name']
        
        # perfume 
        perfume_name = perfume_data['perfume_name']
        
        image_url = perfume_data.get('image_src')
        if (image_url == None):
            image_not_exist_perfume_count += 1
            print(f"향수 섬네일 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
        
        
        top_notes = perfume_data['notes'].get("Top Notes")
        middle_notes = perfume_data['notes'].get("Middle Notes")
        base_notes = perfume_data['notes'].get("Base Notes")
        undefineded_notes = perfume_data['notes'].get("Undefineded")
        if (top_notes == middle_notes == base_notes == undefineded_notes == None):
            note_error_perfume_count += 1
            print(f"노트 정보 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
            
        
print("===========all checked===========")
print(f"총 향수 개수: {total_perfume_count}")
print(f"이미지 없는 향수 개수: {image_not_exist_perfume_count}")
print(f"Top/Middle/Base 노트 정보 없는 향수 개수: {note_error_perfume_count}")
