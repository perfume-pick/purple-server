# %% [markdown]
# # 향수 상세정보 크롤링 데이터 적재 스크립트
# ## 관련 테이블 정보
# - evaluation_code, evaluation_field_option, fragrantica_evaluation
# - perfume, perfume_brand
# - pefume_accord, note, perfume_note
#
# ## TODO
# - 이슈 사항에 대한 처리
# - perfume_brand: 초기 display_order, image_url 추가
# - perfume: image_url에 대해 s3 url로 변경(현재 프라그란티카 url)
# - 한영 dictionary를 이용하여 한글로 변환 후 적재하는 로직 추가

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /Users/jeongdongjun/opt/anaconda3/lib/python3.8/site-packages (1.1.1)

# %%
# test
import pymysql


# MySQL 연결 설정
conn = pymysql.connect(
    host='127.0.0.1', 
    port=3306,
    user='root', 
    password='secret', 
    db='purple', 
    charset='utf8'
)

cursor = conn.cursor()

sql = "SHOW TABLES;"
cursor.execute(sql)
result = cursor.fetchall()
for table in result:
    print(table[0])

conn.commit()
conn.close()
# Out:
# evaluation_code
# evaluation_field_option
# favorite
# fragrantica_evaluation
# note
# perfume
# perfume_accord
# perfume_brand
# perfume_note
# rating
# review
# user
# user_preference_note

# %%
import os
import json

# JSON 데이터
DIRECTORY_PATH = './crawling_data'
JSON_DATA_LIST = []
for filename in os.listdir(DIRECTORY_PATH):
    if filename.endswith('.json'):
        file_path = os.path.join(DIRECTORY_PATH, filename)
        
        with open(file_path, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
            JSON_DATA_LIST.append(data)

# %%
# code set
evaluation_codes = {
	"LONGEVITY": {
		"code": "EF001",
		"name": "지속력",
		"type": "FIELD",
		"options": {
			"very weak": {
				"code": "EO101",
				"name": "매우 약함",
				"type": "OPTION"
			},
			"weak": {
				"code": "EO102",
				"name": "약함",
				"type": "OPTION"
			},
			"moderate": {
				"code": "EO103",
				"name": "보통",
				"type": "OPTION"
			},
			"long lasting": {
				"code": "EO104",
				"name": "오래감",
				"type": "OPTION"
			},
			"eternal": {
				"code": "EO105",
				"name": "매우 오래감",
				"type": "OPTION"
			}
		}
	},
	"SILLAGE": {
		"code": "EF002",
		"name": "시야주",
		"type": "FIELD",
		"options": {
			"intimate": {
				"code": "EO201",
				"name": "향 여운이 약함",
				"type": "OPTION"
			},
			"moderate": {
				"code": "EO202",
				"name": "보통",
				"type": "OPTION"
			},
			"strong": {
				"code": "EO203",
				"name": "향 여운이 강함",
				"type": "OPTION"
			},
			"enormous": {
				"code": "EO204",
				"name": "향 여운이 매우 강함",
				"type": "OPTION"
			}
		}
	},
	"seasonData": {
		"code": "EF003",
		"name": "계절감/시간",
		"type": "FIELD",
		"options": {
			"spring": {
				"code": "EO301",
				"name": "봄",
				"type": "OPTION"
			},
			"summer": {
				"code": "EO302",
				"name": "여름",
				"type": "OPTION"
			},
			"fall": {
				"code": "EO303",
				"name": "가을",
				"type": "OPTION"
			},
			"winter": {
				"code": "EO304",
				"name": "겨울",
				"type": "OPTION"
			},
			"day": {
				"code": "EO305",
				"name": "낮",
				"type": "OPTION"
			},
			"night": {
				"code": "EO306",
				"name": "밤",
				"type": "OPTION"
			}
		}
	},
	"GENDER": {
		"code": "EF004",
		"name": "성별",
		"type": "FIELD",
		"options": {
			"male": {
				"code": "EO401",
				"name": "남성",
				"type": "OPTION"
			},
			"more male": {
				"code": "EO402",
				"name": "남성에 가까운",
				"type": "OPTION"
			},
			"unisex": {
				"code": "EO403",
				"name": "중성",
				"type": "OPTION"
			},
			"more female": {
				"code": "EO404",
				"name": "여성에 가까운",
				"type": "OPTION"
			},
			"female": {
				"code": "EO405",
				"name": "여성",
				"type": "OPTION"
			}
		}
	}
}

# %%
from datetime import datetime

def generate_id():
    '''
    현재 시간을 yyyyMMddHHmmssSSSSS 형식으로 포맷팅 후 int로 변환
    '''
    return int(datetime.now().strftime('%Y%m%d%H%M%S%f')[:-1])

def get_or_generate_id(query, variables):
    cursor.execute(query, variables)
    result = cursor.fetchone()
    return generate_id() if result == None else result[0]

# %%
# sql_queries

# insert
insert_evaluation_code_query = (
    "INSERT IGNORE INTO "
    "evaluation_code(code, name, type) "
    "VALUES(%s, %s, %s);"
)
insert_evaluation_field_option_query = (
    "INSERT IGNORE INTO "
    "evaluation_field_option("
    "evaluation_field_option_id, field_code, option_code"
    ") "
    "VALUES(%s, %s, %s);"
)

insert_perfume_brand_query = (
    "INSERT IGNORE INTO "
    "perfume_brand(brand_name, image_url, display_order) "
    "VALUES(%s, '', '');"
)
insert_perfume_query = (
    "INSERT INTO "
    "perfume("
    "perfume_id, brand_name, perfume_name, image_url"
    ") "
    "VALUES(%s, %s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "image_url = VALUES(image_url);"
)

insert_fragrantica_evaluation_query = (
    "INSERT INTO "
    "fragrantica_evaluation("
    "fragrantica_evaluation_id, perfume_id, field_code, option_code, votes"
    ") "
    "VALUES(%s, %s, %s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "votes = VALUES(votes);"
)

insert_note_query = (
    "INSERT IGNORE INTO "
    "note(name) "
    "VALUES(%s);"
)
insert_perfume_note_query = (
    "INSERT IGNORE INTO "
    "perfume_note("
    "perfume_note_id, perfume_id, note_name, perfume_note_type"
    ") "
    "VALUES(%s, %s, %s, %s);"
)

insert_perfume_accord_query = (
    "INSERT INTO "
    "perfume_accord("
    "perfume_accord_id, perfume_id, note_name, accord_value"
    ") "
    "VALUES(%s, %s, %s, %s) "
    "ON DUPLICATE KEY UPDATE "
    "accord_value = VALUES(accord_value);"
)

# select id
select_perfume_perfume_id_query = (
    "SELECT perfume_id "
    "FROM perfume "
    "WHERE brand_name=%s AND perfume_name=%s;"
)
select_fragrantica_evaluation_id_query = (
    "SELECT fragrantica_evaluation_id "
    "FROM fragrantica_evaluation "
    "WHERE perfume_id=%s AND field_code=%s AND option_code=%s;"
)
select_perfume_note_id_query = (
    "SELECT perfume_note_id "
    "FROM perfume_note "
    "WHERE perfume_id=%s AND note_name=%s AND perfume_note_type=%s;"
)
select_perfume_accord_id_query = (
    "SELECT perfume_accord_id "
    "FROM perfume_accord "
    "WHERE perfume_id=%s AND note_name=%s;"
)

# %%
import pymysql
            
# MySQL 연결 설정
conn = pymysql.connect(
    host='127.0.0.1', 
    port=3306,
    user='root', 
    password='secret', 
    db='purple', 
    charset='utf8'
)

cursor = conn.cursor()

print("=============insert start=============")
# evaluation_code & evaludation_field_option
for field_key, field_data in evaluation_codes.items():
    
    # evaluation_code(field)
    field_code, field_name, code_type = field_data['code'], field_data['name'], field_data['type'] 
    cursor.execute(insert_evaluation_code_query, (field_code, field_name, code_type))
    
    for option_key, option_data in field_data['options'].items():
        
        # evaluation_code(option)
        option_code, option_name, code_type = option_data['code'], option_data['name'], option_data['type'] 
        cursor.execute(insert_evaluation_code_query, (option_code, option_name, code_type))
        
        # evaluation_field_option
        evaluation_field_option_id = generate_id()
        cursor.execute(
            insert_evaluation_field_option_query, 
            (evaluation_field_option_id, field_code, option_code)
        )

conn.commit()
print("===========evaluation_code & evaludation_field_option complete.===========")

field_key_list = ["seasonData", "LONGEVITY", "SILLAGE", "GENDER"]

for brand_data in JSON_DATA_LIST:
    for perfume_data in brand_data:
        # perfume_brand
        # TODO: 초기 display_order, image_url 추가
        brand_name = perfume_data['companyName']
        cursor.execute(insert_perfume_brand_query, (brand_name))
        
        # perfume 
        # TODO: image_url에 대해 s3 url로 변경(현재 프라그란티카 url)
        perfume_name = perfume_data['perfumeName']
        print(f"start: {brand_name} > {perfume_name}")
        
        perfume_id = get_or_generate_id(
            select_perfume_perfume_id_query,
            (brand_name, perfume_name)
        )
        image_url = perfume_data.get('thumbnailSrc')
        cursor.execute(
            insert_perfume_query, 
            (perfume_id, brand_name, perfume_name, image_url)
        )
        
        # fragrantica_evaluation(seasonData)
        field_code = evaluation_codes['seasonData']['code']
        for option_key, votes in perfume_data['seasonData'].items():
            option_code = evaluation_codes['seasonData']['options'][option_key]['code']
            fragrantica_evaluation_id = get_or_generate_id(
                select_fragrantica_evaluation_id_query,
                (perfume_id, field_code, option_code)
            )
            cursor.execute(
                insert_fragrantica_evaluation_query, 
                (fragrantica_evaluation_id, perfume_id, field_code, option_code, votes)
            )
        
        # fragrantica_evaluation(perfumeProperties)
        for field_key, field_data in perfume_data['perfumeProperties'].items():
            if (field_key not in field_key_list): continue;
            field_code = evaluation_codes[field_key]['code']
            
            for option_key, votes in field_data.items():
                option_code = evaluation_codes[field_key]['options'][option_key]['code']
                fragrantica_evaluation_id = get_or_generate_id(
                    select_fragrantica_evaluation_id_query,
                    (perfume_id, field_code, option_code)
                )
                cursor.execute(
                    insert_fragrantica_evaluation_query, 
                    (fragrantica_evaluation_id, perfume_id, field_code, option_code, votes)
                )
        
        # perfume_accord
        for note_name, accord_value in perfume_data['notes'].items():
            perfume_accord_id = get_or_generate_id(
                select_perfume_accord_id_query,
                (perfume_id, note_name)
            )
            cursor.execute(
                insert_perfume_accord_query, 
                (perfume_accord_id, perfume_id, note_name, accord_value)
            )
        
        
        if (perfume_data['noteTopMiddleBase'].get("Top Notes")):
            for note_name in perfume_data['noteTopMiddleBase'].get("Top Notes"):
                # note
                cursor.execute(insert_note_query, (note_name))
                
                # perfume_note
                perfume_note_type = "TOP"
                perfume_note_id = get_or_generate_id(
                    select_perfume_note_id_query,
                    (perfume_id, note_name, perfume_note_type)
                )
                cursor.execute(
                    insert_perfume_note_query,
                    (perfume_note_id, perfume_id, note_name, perfume_note_type)
                )
                
                
                
        if (perfume_data['noteTopMiddleBase'].get("Middle Notes")):
            for note_name in perfume_data['noteTopMiddleBase'].get("Middle Notes"):
                # note
                cursor.execute(insert_note_query, (note_name))
                
                # perfume_note
                perfume_note_type = "MIDDLE"
                perfume_note_id = get_or_generate_id(
                    select_perfume_note_id_query,
                    (perfume_id, note_name, perfume_note_type)
                )
                cursor.execute(
                    insert_perfume_note_query,
                    (perfume_note_id, perfume_id, note_name, perfume_note_type)
                )
                
        
        if (perfume_data['noteTopMiddleBase'].get("Base Notes")):
            for note_name in perfume_data['noteTopMiddleBase'].get("Base Notes"):
                # note
                cursor.execute(insert_note_query, (note_name))        
                
                # perfume_note
                perfume_note_type = "BASE"
                perfume_note_id = get_or_generate_id(
                    select_perfume_note_id_query,
                    (perfume_id, note_name, perfume_note_type)
                )
                cursor.execute(
                    insert_perfume_note_query,
                    (perfume_note_id, perfume_id, note_name, perfume_note_type)
                )
        print(f"no error: {brand_name} > {perfume_name}")
        
        
conn.commit()
print("===========perfume data committed.===========")

cursor.close()
conn.close()
# Out:
# =============insert start=============
# ===========evaluation_code & evaludation_field_option complete.===========
# start: Marc Jacobs > Daisy Love
# no error: Marc Jacobs > Daisy Love
# start: Marc Jacobs > Daisy Eau So Fresh
# no error: Marc Jacobs > Daisy Eau So Fresh
# start: Marc Jacobs > Daisy Dream
# no error: Marc Jacobs > Daisy Dream
# start: Marc Jacobs > Perfect
# no error: Marc Jacobs > Perfect
# start: Marc Jacobs > Daisy
# no error: Marc Jacobs > Daisy
# start: Marc Jacobs > Daisy Love Pop
# no error: Marc Jacobs > Daisy Love Pop
# start: Marc Jacobs > Daisy Love Eau So Sweet Petals
# no error: Marc Jacobs > Daisy Love Eau So Sweet Petals
# start: Marc Jacobs > Daisy Love Skies
# no error: Marc Jacobs > Daisy Love Skies
# start: Marc Jacobs > Daisy Ever So Fresh
# no error: Marc Jacobs > Daisy Ever So Fresh
# start: Marc Jacobs > Perfect Intense
# no error: Marc Jacobs > Perfect Intense
# start: Byredo > Blanche
# no error: Byredo > Blanche
# start: Byredo > La Tulipe
# no error: Byredo > La Tulipe
# start: Byredo > Rose Of No Man's Land
# no error: Byredo > Rose Of No Man's Land
# start: Byredo > Casablanca Lily
# no error: Byredo > Casablanca Lily
# start: Byredo > Mojave Ghost
# no error: Byredo > Mojave Ghost
# start: Byredo > Pulp
# no error: Byredo > Pulp
# start: Byredo > Inflorescence
# no error: Byredo > Inflorescence
# start: Byredo > Bal d'Afrique
# no error: Byredo > Bal d'Afrique
# start: Byredo > Flowerhead
# no error: Byredo > Flowerhead
# start: Byredo > Young Rose
# no error: Byredo > Young Rose
# start: Byredo > Gypsy Water
# no error: Byredo > Gypsy Water
# start: Byredo > Mixed Emotions
# no error: Byredo > Mixed Emotions
# start: Byredo > Super Cedar
# no error: Byredo > Super Cedar
# start: Byredo > Rose Noir
# no error: Byredo > Rose Noir
# start: Byredo > Accord Oud
# no error: Byredo > Accord Oud
# start: Byredo > Animalique
# no error: Byredo > Animalique
# start: Byredo > Eyes Closed
# no error: Byredo > Eyes Closed
# start: Byredo > Bibliothèque
# no error: Byredo > Bibliothèque
# start: Penhaligon's > Luna
# no error: Penhaligon's > Luna
# start: Penhaligon's > Blenheim Bouquet
# no error: Penhaligon's > Blenheim Bouquet
# start: Penhaligon's > Juniper Sling
# no error: Penhaligon's > Juniper Sling
# start: Penhaligon's > Orange Blossom
# no error: Penhaligon's > Orange Blossom
# start: Penhaligon's > Endymion Concentré
# no error: Penhaligon's > Endymion Concentré
# start: Penhaligon's > Clandestine Clara
# no error: Penhaligon's > Clandestine Clara
# start: Penhaligon's > A Kiss Of Bliss
# no error: Penhaligon's > A Kiss Of Bliss
# start: Penhaligon's > The Inimitable William Penhaligon
# no error: Penhaligon's > The Inimitable William Penhaligon
# start: Penhaligon's > The Favourite
# no error: Penhaligon's > The Favourite
# start: Penhaligon's > Much Ado About The Duke
# no error: Penhaligon's > Much Ado About The Duke
# start: Jo Malone London > Blackberry & Bay Cologne
# no error: Jo Malone London > Blackberry & Bay Cologne
# start: Jo Malone London > English Pear & Freesia
# no error: Jo Malone London > English Pear & Freesia
# start: Jo Malone London > Wood Sage & Sea Salt Cologne
# no error: Jo Malone London > Wood Sage & Sea Salt Cologne
# start: Jo Malone London > Peony & Blush Suede
# no error: Jo Malone London > Peony & Blush Suede
# start: Jo Malone London > Lime Basil & Mandarin
# no error: Jo Malone London > Lime Basil & Mandarin
# start: Jo Malone London > Basil & Neroli
# no error: Jo Malone London > Basil & Neroli
# start: Jo Malone London > English Oak & Hazelnut
# no error: Jo Malone London > English Oak & Hazelnut
# start: Jo Malone London > Wild Bluebell
# no error: Jo Malone London > Wild Bluebell
# start: Jo Malone London > Poppy & Barley
# no error: Jo Malone London > Poppy & Barley
# start: Jo Malone London > Cypress & Grapevine Cologne Intense
# no error: Jo Malone London > Cypress & Grapevine Cologne Intense
# start: Jo Malone London > Nectarine Blossom & Honey
# no error: Jo Malone London > Nectarine Blossom & Honey
# start: Jo Malone London > Velvet Rose & Oud Cologne Intense
# no error: Jo Malone London > Velvet Rose & Oud Cologne Intense
# start: Jo Malone London > Red Roses Cologne
# no error: Jo Malone London > Red Roses Cologne
# start: Jo Malone London > Ginger Beer Cologne
# no error: Jo Malone London > Ginger Beer Cologne
# start: Jo Malone London > Jasmine Sambac & Marigold
# no error: Jo Malone London > Jasmine Sambac & Marigold
# start: Jo Malone London > Rose & Magnolia
# no error: Jo Malone London > Rose & Magnolia
# start: Jo Malone London > Blue Agava & Cacao
# no error: Jo Malone London > Blue Agava & Cacao
# start: Jo Malone London > Vanilla & Anise
# no error: Jo Malone London > Vanilla & Anise
# start: Jo Malone London > White Jasmine & Mint
# no error: Jo Malone London > White Jasmine & Mint
# start: Acqua di Parma > Colonia Essenza Special Edition 2015
# no error: Acqua di Parma > Colonia Essenza Special Edition 2015
# start: Acqua di Parma > Colonia Club
# no error: Acqua di Parma > Colonia Club
# start: Acqua di Parma > Colonia Quercia
# no error: Acqua di Parma > Colonia Quercia
# start: Acqua di Parma > Acqua di Parma Blu Mediterraneo - Fico di Amalfi
# no error: Acqua di Parma > Acqua di Parma Blu Mediterraneo - Fico di Amalfi
# no error: Dior > Dior Homme Cologne 2022
# start: Dior > Dior Homme Intense 2011
# no error: Dior > Dior Homme Intense 2011
# start: Dior > Miss Dior Rose N'Roses
# no error: Dior > Miss Dior Rose N'Roses
# start: Dior > Fahrenheit
# no error: Dior > Fahrenheit
# start: Dior > Forever and Ever Dior
# no error: Dior > Forever and Ever Dior
# start: Dior > J'Adore Infinissime
# no error: Dior > J'Adore Infinissime
# start: Dior > Sauvage Eau de Parfum
# no error: Dior > Sauvage Eau de Parfum
# start: Dior > Sauvage Elixir
# no error: Dior > Sauvage Elixir
# start: Dior > Sauvage
# no error: Dior > Sauvage
# start: Dior > Dior Homme 2020
# no error: Dior > Dior Homme 2020
# start: Kenzo > Flower by Kenzo Eau de Toilette (2021)
# no error: Kenzo > Flower by Kenzo Eau de Toilette (2021)
# start: Kenzo > L'Eau par Kenzo pour Homme
# no error: Kenzo > L'Eau par Kenzo pour Homme
# start: Kenzo > Flower by Kenzo Poppy Bouquet Eau de Parfum
# no error: Kenzo > Flower by Kenzo Poppy Bouquet Eau de Parfum
# start: Kenzo > Flower by Kenzo
# no error: Kenzo > Flower by Kenzo
# start: Kenzo > Kenzo Homme Eau de Parfum
# no error: Kenzo > Kenzo Homme Eau de Parfum
# start: Kenzo > Kenzo World Power
# no error: Kenzo > Kenzo World Power
# start: Kenzo > Kenzo Homme Eau de Toilette
# no error: Kenzo > Kenzo Homme Eau de Toilette
# start: Kenzo > Flower by Kenzo L'Absolue
# no error: Kenzo > Flower by Kenzo L'Absolue
# start: Kenzo > Ciel Magnolia
# no error: Kenzo > Ciel Magnolia
# start: Calvin Klein > CK be
# no error: Calvin Klein > CK be
# start: Calvin Klein > CK One
# no error: Calvin Klein > CK One
# start: Calvin Klein > CK All
# no error: Calvin Klein > CK All
# start: Calvin Klein > CK One Gold
# no error: Calvin Klein > CK One Gold
# start: Calvin Klein > Eternity for Women Reflections
# no error: Calvin Klein > Eternity for Women Reflections
# start: Calvin Klein > Eternity for Men Eau de Parfum
# no error: Calvin Klein > Eternity for Men Eau de Parfum
# start: Calvin Klein > Ck One Summer Daze
# no error: Calvin Klein > Ck One Summer Daze
# start: Calvin Klein > CK Free
# no error: Calvin Klein > CK Free
# start: Calvin Klein > CK Everyone Eau de Toilette
# no error: Calvin Klein > CK Everyone Eau de Toilette
# start: Calvin Klein > Euphoria Intense
# no error: Calvin Klein > Euphoria Intense
# start: Calvin Klein > CK IN2U for Him
# no error: Calvin Klein > CK IN2U for Him
# start: Calvin Klein > Obsession
# no error: Calvin Klein > Obsession
# start: Diptyque > Fleur de Peau Eau de Parfum
# no error: Diptyque > Fleur de Peau Eau de Parfum
# start: Diptyque > Tam Dao Eau de Parfum
# no error: Diptyque > Tam Dao Eau de Parfum
# start: Diptyque > Tam Dao Eau de Toilette
# no error: Diptyque > Tam Dao Eau de Toilette
# start: Diptyque > Do Son Eau de Parfum
# no error: Diptyque > Do Son Eau de Parfum
# start: Diptyque > Do Son Eau de Toilette
# no error: Diptyque > Do Son Eau de Toilette
# start: Diptyque > Eau des Sens Eau de Toilette
# no error: Tom Ford > Noir de Noir
# start: Tom Ford > Bitter Peach
# no error: Tom Ford > Bitter Peach
# start: Tom Ford > Soleil Neige
# no error: Tom Ford > Soleil Neige
# start: Tom Ford > Electric Cherry
# no error: Tom Ford > Electric Cherry
# start: Tom Ford > Myrrhe Mystère
# no error: Tom Ford > Myrrhe Mystère
# start: Gucci > Flora Gorgeous Gardenia Eau de Parfum
# no error: Gucci > Flora Gorgeous Gardenia Eau de Parfum
# start: Gucci > Flora Gorgeous Jasmine
# no error: Gucci > Flora Gorgeous Jasmine
# start: Gucci > A Song For The Rose Eau de Parfum
# no error: Gucci > A Song For The Rose Eau de Parfum
# start: Gucci > Guilty Pour Homme Eau de Parfum
# no error: Gucci > Guilty Pour Homme Eau de Parfum
# start: Gucci > Gucci Guilty Absolute pour Femme
# no error: Gucci > Gucci Guilty Absolute pour Femme
# start: Gucci > Gucci Bloom Intense
# no error: Gucci > Gucci Bloom Intense
# start: Gucci > Gucci Guilty Love Edition Pour Homme
# no error: Gucci > Gucci Guilty Love Edition Pour Homme
# start: Gucci > Gucci Guilty Eau de Parfum Intense Pour Femme
# no error: Gucci > Gucci Guilty Eau de Parfum Intense Pour Femme
# start: Gucci > Gucci Bloom Nettare Di Fiori
# no error: Gucci > Gucci Bloom Nettare Di Fiori
# start: Gucci > Gucci Bloom Profumo Di Fiori
# no error: Gucci > Gucci Bloom Profumo Di Fiori
# start: Gucci > A Reason To Love
# no error: Gucci > A Reason To Love
# start: Gucci > Flora Gorgeous Magnolia
# no error: Gucci > Flora Gorgeous Magnolia
# start: Gucci > Bloom Eau de Toilette
# no error: Gucci > Bloom Eau de Toilette
# start: Gucci > Gucci Bamboo Eau de Toilette
# no error: Gucci > Gucci Bamboo Eau de Toilette
# start: Gucci > Gucci Guilty Eau de Parfum
# no error: Gucci > Gucci Guilty Eau de Parfum
# start: Gucci > Mémoire d’une Odeur
# no error: Gucci > Mémoire d’une Odeur
# start: Gucci > Gucci Bloom Ambrosia di Fiori
# no error: Gucci > Gucci Bloom Ambrosia di Fiori
# start: Clean > Air & Coconut Water Eau Fraiche
# no error: Clean > Air & Coconut Water Eau Fraiche
# start: Clean > Clean Warm Cotton
# no error: Clean > Clean Warm Cotton
# start: Clean > Cool Cotton
# no error: Clean > Cool Cotton
# start: Clean > Clean Classic Warm Cotton
# no error: Clean > Clean Classic Warm Cotton
# start: Clean > Clean Shower Fresh
# no error: Clean > Clean Shower Fresh
# start: Clean > Pure Soap
# no error: Clean > Pure Soap
# start: Clean > Fresh Linens
# no error: Clean > Fresh Linens
# start: Clean > Rain
# no error: Clean > Rain
# start: Clean > Warm Cotton [Reserve Blend]
# no error: Clean > Warm Cotton [Reserve Blend]
# start: Clean > Acqua Neroli
# no error: Clean > Acqua Neroli
# start: Clean > Citron Fig
# no error: Clean > Citron Fig
# start: Clean > Sueded Oud
# no error: Clean > Sueded Oud
# start: Clean > Skin
# no error: Clean > Skin
# start: Clean > Radiant Nectar
# no error: Clean > Radiant Nectar
# start: Clean > Clean Classic Flower Fresh
# no error: Clean > Clean Classic Flower Fresh
# start: Clean > Clean Air
# no error: Clean > Clean Air
# start: Ferrari > Ferrari Black
# no error: Ferrari > Ferrari Black
# start: Ferrari > Scuderia Ferrari Light Essence Bright
# no error: Ferrari > Scuderia Ferrari Light Essence Bright
# start: Ferrari > Noble Fig
# no error: Ferrari > Noble Fig
# start: Ferrari > Cedar Essence
# no error: Ferrari > Cedar Essence
# start: Ferrari > Bright Neroli
# no error: Ferrari > Bright Neroli
# start: Ferrari > Ferrari Light Essence
# no error: Ferrari > Ferrari Light Essence
# start: Ferrari > Vetiver Essence
# no error: Ferrari > Vetiver Essence
# start: Ferrari > Red Power
# no error: Ferrari > Red Power
# start: Ferrari > Ferrari Uomo
# no error: Ferrari > Ferrari Uomo
# start: Ferrari > Pure Lavender
# no error: Ferrari > Pure Lavender
# start: Versace > Bright Crystal Absolu
# no error: Versace > Bright Crystal Absolu
# start: Versace > Bright Crystal
# no error: Versace > Bright Crystal
# start: Versace > Eros
# no error: Versace > Eros
# start: Versace > Versace Pour Homme
# no error: Versace > Versace Pour Homme
# start: Versace > Red Jeans
# no error: Versace > Red Jeans
# start: Versace > The Dreamer
# no error: Versace > The Dreamer
# start: Versace > Versace Pour Homme Dylan Blue
# no error: Versace > Versace Pour Homme Dylan Blue
# start: Versace > Santal Boisé
# no error: Versace > Santal Boisé
# start: Versace > Crystal Noir Eau de Toilette
# no error: Versace > Crystal Noir Eau de Toilette
# start: Versace > Eros Pour Femme
# no error: Versace > Eros Pour Femme
# start: Versace > Eros Flame
# no error: Versace > Eros Flame
# start: Versace > Versace Pour Femme Dylan Blue
# no error: Versace > Versace Pour Femme Dylan Blue
# start: Versace > Eros Eau de Parfum
# no error: Versace > Eros Eau de Parfum
# start: Creed > Aventus
# no error: Creed > Aventus
# start: Creed > Love in White
# no error: Creed > Love in White
# start: Creed > Tabarome
# no error: Creed > Tabarome
# start: Creed > Aventus for Her
# no error: Creed > Aventus for Her
# start: Creed > Virgin Island Water
# no error: Creed > Virgin Island Water
# start: Creed > Green Irish Tweed
# no error: Creed > Green Irish Tweed
# start: Creed > Queen of Silk
# no error: Creed > Queen of Silk
# start: Creed > Silver Mountain Water
# no error: Creed > Silver Mountain Water
# start: Creed > Millésime Impérial
# no error: Creed > Millésime Impérial
# start: Creed > Acqua Fiorentina
# no error: Creed > Acqua Fiorentina
# start: Creed > Original Vetiver
# no error: Creed > Original Vetiver
# start: Creed > Royal Mayfair
# no error: Creed > Royal Mayfair
# start: Creed > Zeste Mandarine
# no error: Creed > Zeste Mandarine
# start: Creed > Spring Flower
# no error: Creed > Spring Flower
# start: Creed > Wind Flowers
# no error: Creed > Wind Flowers
# start: Creed > Love in White for Summer
# no error: Creed > Love in White for Summer
# start: Creed > Vetiver Geranium
# no error: Creed > Vetiver Geranium
# start: Creed > Floralie
# no error: Creed > Floralie
# start: Creed > Vetiver
# no error: Creed > Vetiver
# start: Creed > Royal Water
# no error: Creed > Royal Water
# start: Creed > Aventus Cologne
# no error: Creed > Aventus Cologne
# start: Creed > Himalaya
# no error: Creed > Himalaya
# ===========perfume data committed.===========

# %% [markdown]
# # 이슈: 필요 데이터가 없는 경우 확인

# %%
total_perfume_count = 0
note_error_perfume_count = 0
image_not_exist_perfume_count = 0

print("===========start checking===========")
for brand_data in JSON_DATA_LIST:
    total_perfume_count += len(brand_data)
    for perfume_data in brand_data:
        # perfume_brand
        brand_name = perfume_data['companyName']
        
        # perfume 
        perfume_name = perfume_data['perfumeName']
        
        image_url = perfume_data.get('thumbnailSrc')
        if (image_url == None):
            image_not_exist_perfume_count += 1
            print(f"향수 섬네일 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
        
        
        top_notes = perfume_data['noteTopMiddleBase'].get("Top Notes")
        middle_notes = perfume_data['noteTopMiddleBase'].get("Middle Notes")
        base_notes = perfume_data['noteTopMiddleBase'].get("Base Notes")
        if (top_notes == middle_notes == base_notes == None):
            note_error_perfume_count += 1
            print(f"Top/Middle/Base 노트 정보 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
            
        elif (top_notes == None):
            print(f"Top 노트 정보 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
                
                
                
        elif (middle_notes == None):
            print(f"Middle 노트 정보 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
                
        
        elif (base_notes == None):
            print(f"Base 노트 정보 없음 <- 브랜드명: {brand_name}, 향수명: {perfume_name}")
        
        
        
print("===========all checked===========")
print(f"총 향수 개수: {total_perfume_count}")
print(f"이미지 없는 향수 개수: {image_not_exist_perfume_count}")
print(f"Top/Middle/Base 노트 정보 없는 향수 개수: {note_error_perfume_count}")
# Out:
# ===========start checking===========
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Penhaligon's, 향수명: Blenheim Bouquet
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Penhaligon's, 향수명: Clandestine Clara
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Penhaligon's, 향수명: Much Ado About The Duke
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Jo Malone London, 향수명: Poppy & Barley
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Jo Malone London, 향수명: Cypress & Grapevine Cologne Intense
# 향수 섬네일 없음 <- 브랜드명: Jo Malone London, 향수명: Ginger Beer Cologne
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Acqua di Parma, 향수명: Acqua di Parma Blu Mediterraneo - Fico di Amalfi
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Acqua di Parma, 향수명: Essenza di Colonia
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Acqua di Parma, 향수명: Peonia Nobile
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Chloé, 향수명: Jasminum Sambac
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Bergamote 22
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Santal 33
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: The Matcha 26
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Baie 19
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Fleur d'Oranger 27
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Lys 41
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Jasmin 17
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Tonka 25
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Ylang 49
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Le Labo, 향수명: Vetiver 46
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Lust
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Dirty
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Vanillary
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Breath Of God
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: All Good Things
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Sun
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Imogen Rose
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Devil's Night Cap
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Lush, 향수명: Amelie Mae
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Chanel, 향수명: Gabrielle Parfum Chanel
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Dior, 향수명: J'Adore Roller Pearl
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Kenzo, 향수명: L'Eau par Kenzo pour Homme
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Diptyque, 향수명: Tam Dao Eau de Parfum
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Diptyque, 향수명: Do Son Eau de Parfum
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Diptyque, 향수명: L'Ombre Dans L'Eau Eau de Toilette
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Tom Ford, 향수명: Oud Wood
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Tom Ford, 향수명: Myrrhe Mystère
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Gucci, 향수명: A Song For The Rose Eau de Parfum
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Clean, 향수명: Skin
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Ferrari, 향수명: Ferrari Light Essence
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Versace, 향수명: Santal Boisé
# Top/Middle/Base 노트 정보 없음 <- 브랜드명: Creed, 향수명: Zeste Mandarine
# ===========all checked===========
# 총 향수 개수: 329
# 이미지 없는 향수 개수: 1
# Top/Middle/Base 노트 정보 없는 향수 개수: 41
